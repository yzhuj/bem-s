# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('./helper_functions')
sys.path.append('./helper_functions/bemColors_lib')
sys.path.append('../../Electrodes')
from helper_functions import plot_mesh
from bemColors import bemColors
import pickle
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from bem import Electrodes, Sphere, Mesh, Grid, Configuration, Result
from bem.formats import stl

from multipoles import MultipoleControl
from plottingfuncns import *

from time import time
from helper_functions import run_job, write_pickle

stl_unit = 1e-3 # meters

# this is the unit for our Mesh structure
# in the following code, this is the default unit for python variables
mesh_unit = 1e-3 # meters

# %%
prefix = './pkls/glasstrapcolor'
mesh_unit,xl,yl,zl,grid = pickle.load(open(prefix+'_grid.pkl', 'rb'))

# %%
def plot_potential(electrode='RF', levels=np.linspace(0, 100e-2, 10),fout='fig.png',save=False):
    result = Result.from_pkl(prefix, electrode)
    if electrode=='RF':
        p = result.pseudo_potential
        title = f'RF Pseudopotential (l={np.round(mesh_unit/1e-6,1)} $\mu$m)'
    else:
        p = result.potential
        title = f'{electrode} Potential (l={np.round(mesh_unit/1e-6,1)}$\mu$m)'

    maxp = np.amax(p)
    print("max potential", maxp)

    x = grid.to_mgrid()
    x = grid.to_mgrid()[:, p.shape[0]//2]    # p.shape[0]/2 is in the middle of x.
    p = p[p.shape[0]//2]    # get a slice of yz plane at x = p.shape[0]/2 (x is along trap axis)

    plt.rcParams.update({'font.size': 20})
    fig, ax = plt.subplots(figsize=(8,8))
    ax.set_aspect("equal")
    ct = ax.contour(x[1], x[2], p, levels=levels, cmap=plt.cm.Reds)
    plt.colorbar(ct)
    ax.set_ylabel('z/l')
    ax.set_xlabel('y/l')
    ax.set_title(title)
    ax.grid()

#     plt.savefig(electrode+'.png', bbox_inches='tight')
    plt.show()
    
plot_potential('RF', levels=np.linspace(0, 100e-2, 50))
# plot_potential('DC3', levels=np.linspace(0, 50e-2, 20))
# Out:
# max potential 347.2524693973845

# %%
def plot_potentialf(electrode='RF', levels=np.linspace(0, 100e-2, 10),fout='fig.png',save=False):
    result = Result.from_pkl(prefix, electrode)
    if electrode=='RF':
        p = result.pseudo_potential
        title = f'RF Pseudopotential (l={np.round(mesh_unit/1e-6,1)} $\mu$m)'
    else:
        p = result.potential
        title = f'{electrode} Potential (l={np.round(mesh_unit/1e-6,1)}$\mu$m)'

    maxp = np.amax(p)
    print("max potential", maxp)

    x = grid.to_mgrid()
    print('x = ',grid.to_xyz()[0][p.shape[0]//2])
    x = grid.to_mgrid()[:, p.shape[0]//2]    # p.shape[0]/2 is in the middle of x.
    p = p[p.shape[0]//2]    # get a slice of yz plane at x = p.shape[0]/2 (x is along trap axis)
    
    plt.rcParams.update({'font.size': 20})
    fig, ax = plt.subplots(figsize=(10,10))
    ax.set_aspect("equal")
#     ax.imshow(p, cmap=plt.cm.Reds)
#     plt.colorbar(ct)
    ct = ax.contour(x[1], x[2], p, levels=levels, cmap=plt.cm.Reds)
    cm = ax.pcolormesh(x[1], x[2], p, cmap=plt.cm.Purples)
    ax.set_ylabel('z/l')
    ax.set_xlabel('y/l')
    ax.set_title(title)
    ax.grid()
    plt.colorbar(ct)
    plt.colorbar(cm)
#     plt.tight_layout()

#     plt.savefig(electrode+'.png', bbox_inches='tight')
    plt.show()
    
plot_potentialf('RF', levels=np.linspace(0, 1, 50))
plot_potentialf('DC5', levels=np.linspace(-0.1, 0.1, 50))
# Out:
# max potential 347.2524693973845
# x =  0.007499999999999951
# /home/yi/anaconda3/envs/ele39/lib/python3.9/site-packages/bem/grid.py:54: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   xyz = np.array([np.linspace(c-s*(h-1)/2., c+s*(h-1)/2.,h)
# max potential 0.3515561503354927
# x =  0.007499999999999951

# %%
nROI = 1
roi = [nROI, nROI, nROI]
order = 2

origin = [yl, zl, xl]
print('Origin ', origin)
controlled_electrodes = ['DC1','DC2','DC3','DC4','DC5','DC6','DC7','DC8','DC9','DC10','DC11','DC12','DC13','DC14','DC15','DC16','DC17','DC18','DC19','DC20','DC21']
used_multipoles =['Ex', 'Ey', 'Ez', 'U1', 'U2', 'U3','U4','U5']


# creating trap dictionary
x, y, z = grid.to_xyz()
nx = len(x)
ny = len(y)
nz = len(z)
ntotal = nx * ny * nz

trap = {'X': y,
        'Y': z,
        'Z': x}
    
trap['electrodes'] = {}
for ele in controlled_electrodes:
    result = Result.from_pkl(prefix, ele)
    p = result.potential
    p = np.swapaxes(p, 0, 2)
    p = np.swapaxes(p, 0, 1)
    trap['electrodes'][ele] = {'potential': p}
        
    
s = MultipoleControl(trap, origin, roi, controlled_electrodes, used_multipoles, order)

print('Multipole names:', s.multipole_names)
print('Normalization factors:', s.normalization_factors)
print(s.electrode_names)
# Out:
# Origin  [0.01, 2.075, 0.0]
# Multipole names: ['C', 'Ey', 'Ez', 'Ex', 'U3', 'U4', 'U2', 'U5', 'U1']
# Normalization factors: [0.28209479 0.48860251 0.48860251 0.48860251 1.09254843 1.09254843
#  0.63078313 1.09254843 0.54627422]
# ['DC1', 'DC2', 'DC3', 'DC4', 'DC5', 'DC6', 'DC7', 'DC8', 'DC9', 'DC10', 'DC11', 'DC12', 'DC13', 'DC14', 'DC15', 'DC16', 'DC17', 'DC18', 'DC19', 'DC20', 'DC21']
# /home/yi/anaconda3/envs/ele39/lib/python3.9/site-packages/bem/grid.py:54: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   xyz = np.array([np.linspace(c-s*(h-1)/2., c+s*(h-1)/2.,h)

# %%
v0 = pd.Series(np.zeros(len(controlled_electrodes)), index=controlled_electrodes)
vs = []
for ele in s.electrode_names:
    v = v0.copy()
    v[ele] = 1
    vs.append(v)
    

heights = np.round(trap['Y'][nROI:] * 1e3)
numMultipoles = len(s.multipole_print_names)
numElectrodes = len(s.electrode_names)
numHeights = len(heights)
multipoles_vs_height = np.zeros(numHeights, numMultipoles, numElectrodes))



# multipoles_vs_height

for i, h in enumerate(heights):
    position = [xl, h*1e-3, zl]
    s.update_origin_roi(position, roi)
    multipoles_vs_height[i] = np.asarray(s.multipole_expansion.loc[s.multipole_names])
    

# s.multipole_expansion.loc['Ex']

# multipoles_vs_height[i] = np.asarray(s.multipole_expansion.loc[s.multipole_names])

# %%
multipoles_vs_height.shape
# Out:
# (33, 9, 21)

# %%
fig, ax = plt.subplots(figsize=(20,10))

for i in range(len(s.electrode_names)):
    ax.plot(heights, multipoles_vs_height[:,2,i], label=f'{s.multipole_names[2]} {s.electrode_names[i]}')

ax.set_xlabel('Height (um)')
ax.set_ylabel('Multipole Coefficient')
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.savefig('multipoles.png', bbox_inches='tight')
plt.show()
